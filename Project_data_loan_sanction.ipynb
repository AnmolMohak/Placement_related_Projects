# %% [markdown]
# <a href="https://colab.research.google.com/github/AnmolMohak/Placement_related_Projects/blob/main/Project_data_loan_sanction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_excel('/content/Project_Data_Loan_sanction.xlsx')

# %% [markdown]
# Question 1
#
# Ans = 0 duplicates

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, Applicant_Income, Coapplicant_Income, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area]
# Index: []

# %% [markdown]
# Question 2

# %% [markdown]
# Question 3
# Ans = only null value in " Dependents"

# %%
df.isnull().sum()
# Out:
# Loan_ID                0
# Gender                 0
# Married                0
# Dependents            10
# Education              0
# Self_Employed          0
# Applicant_Income       0
# Coapplicant_Income     0
# LoanAmount             0
# Loan_Amount_Term       0
# Credit_History         0
# Property_Area          0
# dtype: int64

# %% [markdown]
# Question 4

# %%
df[df['Dependents'].isnull()].shape
# Out:
# (10, 12)

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# Applicant_Income      0
# Coapplicant_Income    0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# dtype: int64

# %% [markdown]
# Question 5

# %%
# no null values.

# %% [markdown]
# Question 6

# %%
# no null values.

# %% [markdown]
# Question 7

# %%
#no null values.

# %% [markdown]
# Question 8

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    Applicant_Income  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# 0              5720                   0         110               360
# 1              3076                1500         126               360
# 2              5000                1800         208               360
# 3              2340                2546         100               360
# 4              3276                   0          78               360
#
#    Credit_History Property_Area
# 0               1         Urban
# 1               1         Urban
# 2               1         Urban
# ...

# %% [markdown]
# Question 9

# %%
df.to_csv('Project_Data_Loan_sanction.csv')

# %% [markdown]
# Questio 10

# %%
row,coloumn=df.shape
print(f"No of rows in : {row} ")
print(f"No of coloumn in : {coloumn}")
# Out:
# No of rows in : 357
# No of coloumn in : 12

# %% [markdown]
# QUestion 11

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Applicant_Income', 'Coapplicant_Income', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %% [markdown]
# Question 12

# %%
df.describe()
# Out:
#        Applicant_Income  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# count        357.000000          357.000000  357.000000        357.000000
# mean        4793.602241         1587.098039  136.501401        343.282913
# std         4936.879103         2357.321156   61.503523         64.015457
# min            0.000000            0.000000   28.000000          6.000000
# 25%         2858.000000            0.000000  102.000000        360.000000
# 50%         3786.000000         1025.000000  125.000000        360.000000
# 75%         5062.000000         2458.000000  158.000000        360.000000
# max        72529.000000        24000.000000  550.000000        480.000000
#
#        Credit_History
# count           357.0
# mean              1.0
# std               0.0
# min               1.0
# 25%               1.0
# 50%               1.0
# 75%               1.0
# max               1.0

# %% [markdown]
# Question 13

# %%
df_integer=df.select_dtypes(include=["int64"])
df[df_integer.columns]
# Out:
#      Applicant_Income  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# 0                5720                   0         110               360
# 1                3076                1500         126               360
# 2                5000                1800         208               360
# 3                2340                2546         100               360
# 4                3276                   0          78               360
# ..                ...                 ...         ...               ...
# 362              4009                1777         113               360
# 363              4158                 709         115               360
# 364              3250                1993         126               360
# 365              5000                2393         158               360
# 366              9200                   0          98               180
#
#      Credit_History
# 0                 1
# 1                 1
# 2                 1
# ...

# %% [markdown]
# Question 14

# %%
df_integer.head()
# Out:
#    Applicant_Income  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# 0              5720                   0         110               360
# 1              3076                1500         126               360
# 2              5000                1800         208               360
# 3              2340                2546         100               360
# 4              3276                   0          78               360
#
#    Credit_History
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %% [markdown]
# Question 15

# %%
df[df['Self_Employed']=='Yes'].head()
# Out:
#      Loan_ID Gender Married Dependents     Education Self_Employed  \
# 5   LP001054   Male     Yes          0  Not Graduate           Yes
# 37  LP001210   Male     Yes          0      Graduate           Yes
# 38  LP001211   Male      No          0      Graduate           Yes
# 49  LP001270   Male     Yes         3+  Not Graduate           Yes
# 54  LP001312   Male     Yes          0  Not Graduate           Yes
#
#     Applicant_Income  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# 5               2165                3422         152               360
# 37              2267                2792          90               360
# 38              5833                   0         116               360
# 49              8000                 250         187               360
# 54              5293                   0          92               360
#
#     Credit_History Property_Area
# 5                1         Urban
# 37               1         Urban
# ...

# %% [markdown]
# Question 16

# %%
df[df['Property_Area']=='Urban']
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001015    Male     Yes          0      Graduate            No
# 1    LP001022    Male     Yes          1      Graduate            No
# 2    LP001031    Male     Yes          2      Graduate            No
# 3    LP001035    Male     Yes          2      Graduate            No
# 4    LP001051    Male      No          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 356  LP002935    Male     Yes          1      Graduate            No
# 357  LP002952    Male      No          0      Graduate            No
# 360  LP002965  Female     Yes          0      Graduate            No
# 362  LP002971    Male     Yes         3+  Not Graduate           Yes
# 363  LP002975    Male     Yes          0      Graduate            No
#
#      Applicant_Income  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df.groupby('Gender').mean()
# Out:
# <ipython-input-168-1bea18cda63a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').mean()
#         Applicant_Income  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# Gender
# Female       4163.600000         1171.957143  126.771429        350.914286
# Male         4956.912458         1663.292929  138.151515        340.915825
#
#         Credit_History
# Gender
# Female             1.0
# Male               1.0
